# %%
import os, ast, sqlite3
import pandas as pd

# %%
os.listdir('../')
# Out:
# ['Analysis', 'Dash', 'Hardware', 'Sensores', 'Server']

# %%
conn = sqlite3.connect('../server/db.sqlite3')
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = [row[0] for row in cursor.fetchall()]
tables
# Out:
# ['django_migrations',
#  'sqlite_sequence',
#  'auth_group_permissions',
#  'auth_user_groups',
#  'auth_user_user_permissions',
#  'django_admin_log',
#  'django_content_type',
#  'auth_permission',
#  'auth_group',
#  'auth_user',
#  'django_session',
#  'Logs_log']

# %%
df = pd.read_sql_query('SELECT * FROM Logs_log', conn)
df
# Out:
#       id       esp_id                               data  \
# 0    627  5CA7E06062E  {"temperature": 0, "humidity": 0}
# 1    628  5CA7E06062E  {"temperature": 0, "humidity": 0}
# 2    629  5CA7E06062E  {"temperature": 0, "humidity": 0}
# 3    630  5CA7E06062E  {"temperature": 0, "humidity": 0}
# 4    631  5CA7E06062E  {"temperature": 0, "humidity": 0}
# ..   ...          ...                                ...
# 179  806  5CA7E06062E  {"temperature": 0, "humidity": 0}
# 180  807  5CA7E06062E  {"temperature": 0, "humidity": 0}
# 181  808  5CA7E06062E  {"temperature": 0, "humidity": 0}
# 182  809  5CA7E06062E  {"temperature": 0, "humidity": 0}
# 183  810  5CA7E06062E  {"temperature": 0, "humidity": 0}
#
#                            date
# 0    2025-07-09 16:32:33.839592
# 1    2025-07-09 16:32:34.333711
# 2    2025-07-09 16:32:35.829321
# 3    2025-07-09 16:34:33.848503
# 4    2025-07-09 16:34:34.375602
# ..                          ...
# 179  2025-07-09 17:16:35.288841
# 180  2025-07-09 17:17:33.898643
# 181  2025-07-09 17:17:34.441030
# 182  2025-07-09 17:17:34.783960
# 183  2025-07-09 17:17:35.303398
#
# [184 rows x 4 columns]

# %%
df['data'] = df.data.apply(ast.literal_eval)
df
# Out:
#       id       esp_id                               data  \
# 0    627  5CA7E06062E  {'temperature': 0, 'humidity': 0}
# 1    628  5CA7E06062E  {'temperature': 0, 'humidity': 0}
# 2    629  5CA7E06062E  {'temperature': 0, 'humidity': 0}
# 3    630  5CA7E06062E  {'temperature': 0, 'humidity': 0}
# 4    631  5CA7E06062E  {'temperature': 0, 'humidity': 0}
# ..   ...          ...                                ...
# 179  806  5CA7E06062E  {'temperature': 0, 'humidity': 0}
# 180  807  5CA7E06062E  {'temperature': 0, 'humidity': 0}
# 181  808  5CA7E06062E  {'temperature': 0, 'humidity': 0}
# 182  809  5CA7E06062E  {'temperature': 0, 'humidity': 0}
# 183  810  5CA7E06062E  {'temperature': 0, 'humidity': 0}
#
#                            date
# 0    2025-07-09 16:32:33.839592
# 1    2025-07-09 16:32:34.333711
# 2    2025-07-09 16:32:35.829321
# 3    2025-07-09 16:34:33.848503
# 4    2025-07-09 16:34:34.375602
# ..                          ...
# 179  2025-07-09 17:16:35.288841
# 180  2025-07-09 17:17:33.898643
# 181  2025-07-09 17:17:34.441030
# 182  2025-07-09 17:17:34.783960
# 183  2025-07-09 17:17:35.303398
#
# [184 rows x 4 columns]

# %% [markdown]
# # DASBOARD

# %%
import dash
from dash import html, dcc
import plotly.express as px
